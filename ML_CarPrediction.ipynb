# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
pd.set_option("display.max_columns",None)

# %%
df = pd.read_excel("C:\\Datasets\\Suicides.xlsx")
df.head()
# Out:
#            State  Year Type_code                                     Type  \
# 0  A & N Islands  2001    Causes                       Illness (Aids/STD)
# 1  A & N Islands  2001    Causes  Bankruptcy or Sudden change in Economic
# 2  A & N Islands  2001    Causes  Cancellation/Non-Settlement of Marriage
# 3  A & N Islands  2001    Causes        Physical Abuse (Rape/Incest Etc.)
# 4  A & N Islands  2001    Causes                            Dowry Dispute
#
#    Gender Age_group  Total
# 0  Female      0-14      0
# 1  Female      0-14      0
# 2  Female      0-14      0
# 3  Female      0-14      0
# 4  Female      0-14      0

# %%
female_df = df[df["Gender"]=="Female"]

# %%
female_df.sample(frac=0.1)
# Out:
#                   State  Year             Type_code  \
# 70882               Goa  2007                Causes
# 96960   Jammu & Kashmir  2005                Causes
# 182039       Puducherry  2012                Causes
# 58999       Daman & Diu  2009  Professional_Profile
# 185894           Punjab  2007                Causes
# ...                 ...   ...                   ...
# 144140          Manipur  2004  Professional_Profile
# 144142          Manipur  2004  Professional_Profile
# 34465        Chandigarh  2002                Causes
# 23157             Assam  2006                Causes
# 50246      D & N Haveli  2006                Causes
#
#                                        Type  Gender Age_group  Total
# 70882     Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 96960                      Property Dispute  Female     30-44      0
# 182039                   Illness (Aids/STD)  Female       60+      0
# ...

# %%
house_df = pd.read_csv("C:\\Datasets\\NewData.csv")

# %%
house_df.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1206  1207          20       RH          NaN     8900   Pave   NaN      Reg
# 372    373         120       RL         50.0     7175   Pave   NaN      Reg
# 966    967          50       RL        130.0     9600   Pave   NaN      IR1
# 728    729          90       RL         85.0    11475   Pave   NaN      Reg
# 52      53          90       RM        110.0     8472   Grvl   NaN      IR2
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1206         Lvl    AllPub    Inside       Gtl      SawyerW       Norm
# 372          Lvl    AllPub    Inside       Gtl      SawyerW       Norm
# 966          HLS    AllPub    Inside       Gtl      Crawfor       Norm
# 728          Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 52           Bnk    AllPub    Corner       Mod       IDOTRR       RRNn
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris["target_names"]
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris["feature_names"]
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df = pd.DataFrame(iris["data"],columns=iris["feature_names"])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df["target"] = iris.target
df.sample(5)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 83                 6.0               2.7                5.1               1.6
# 66                 5.6               3.0                4.5               1.5
# 72                 6.3               2.5                4.9               1.5
# 148                6.2               3.4                5.4               2.3
# 79                 5.7               2.6                3.5               1.0
#
#      target
# 83        1
# 66        1
# 72        1
# 148       2
# 79        1

# %%
df[df["target"]==1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1

# %%
df["flower_name"] = df.target.apply(lambda x: iris.target_names[x])
df.sample(5)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 35                 5.0               3.2                1.2               0.2
# 102                7.1               3.0                5.9               2.1
# 28                 5.2               3.4                1.4               0.2
# 74                 6.4               2.9                4.3               1.3
#
#      target flower_name
# 100       2   virginica
# 35        0      setosa
# 102       2   virginica
# 28        0      setosa
# 74        1  versicolor

# %%
df0 = df[:50]
df1 = df[50:100]
df2 = df[100:]

# %%
df0.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target', 'flower_name'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Stosa vs Versicolor")
plt.xlabel("Petal length")
plt.ylabel("Petel width")
plt.scatter(df0["petal length (cm)"], df0["petal width (cm)"], color="green", marker="+")
plt.scatter(df1["petal length (cm)"], df1["petal width (cm)"], color="red", marker=".")

# %%
plt.title("virginica vs Versicolor")
plt.xlabel("Petal length")
plt.ylabel("Petel width")
plt.scatter(df2["petal length (cm)"], df2["petal width (cm)"], color="green", marker="+")
plt.scatter(df1["petal length (cm)"], df1["petal width (cm)"], color="red", marker=".")

# %%
plt.title("virginica vs Versicolor vs setosa")
plt.xlabel("Petal length")
plt.ylabel("Petel width")
plt.scatter(df2["petal length (cm)"], df2["petal width (cm)"], color="green", marker="+")
plt.scatter(df1["petal length (cm)"], df1["petal width (cm)"], color="red", marker=".")
plt.scatter(df0["petal length (cm)"], df0["petal width (cm)"], color="yellow", marker=".")

# %%
X = df.drop(["target","flower_name"],axis=1)
y = df.target

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=34)
X_test.shape, X_train.shape
# Out:
# ((30, 4), (120, 4))

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred = knn.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.94      1.00      0.97        15
#            2       1.00      0.75      0.86         4
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.92      0.94        30
# weighted avg       0.97      0.97      0.96        30

# %%
df.loc[102]
# Out:
# sepal length (cm)          7.1
# sepal width (cm)           3.0
# petal length (cm)          5.9
# petal width (cm)           2.1
# target                       2
# flower_name          virginica
# Name: 102, dtype: object

# %%
iris.target_names[knn.predict([[7.1,2.0,5.9,2.1]])[0]]
# Out:
# C:\Users\rawat\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 'virginica'

# %%
from sklearn.metrics import f1_score

# %%
k_value = []
train_f1_score = []
test_f1_score = []

for i in range(1,20,2):
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train,y_train)
    train_f1_score.append(f1_score(y_train,model.predict(X_train),average="micro"))
    test_f1_score.append(f1_score(y_test,model.predict(X_test),average="micro"))
    k_value.append(i)

# %%
plt.plot(k_value,train_f1_score,color="green")
plt.plot(k_value,test_f1_score,color="red")
plt.legend(["Train Score","Test Score"])
plt.xlabel("Number of Neighbors")
plt.ylabel("F1_Score")
plt.title("Test vs Train Accuracy")
# Out:
# Text(0.5, 1.0, 'Test vs Train Accuracy')

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

# %%
model = Pipeline([
    ("Scaling",MinMaxScaler()),
    ("KNN",KNeighborsClassifier(n_neighbors=7))
])

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('Scaling', MinMaxScaler()),
#                 ('KNN', KNeighborsClassifier(n_neighbors=7))])

# %%
print(classification_report(y_test,model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00         4
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

sns.heatmap(confusion_matrix(y_test,model.predict(X_test)),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Home Dataset

# %%
import math
sample_size = 500
pop_stdev = house_df["SalePrice"].std()
intervals = []
sample_means = []

for sample in range(25):
    sample = np.random.choice(a=house_df["SalePrice"],size=sample_size)
    sample_mean = sample.mean()
    sample_means.append(sample_mean)

    # get the population standard deviation
    z_critical = stats.norm.ppf(q=0.975)

    # margin of error
    margin_of_error = z_critical * (pop_stdev / math.sqrt(sample_size))
    
    conf_interval = (sample_mean - margin_of_error,
                    sample_mean + margin_of_error)
    print(conf_interval)

    intervals.append(conf_interval)
# Out:
# (168998.70955433298, 182925.33844566703)
# (171124.62355433297, 185051.25244566702)
# (175179.70755433297, 189106.33644566702)
# (172576.25555433298, 186502.88444566703)
# (174876.931554333, 188803.56044566704)
# (171307.98555433296, 185234.61444566702)
# (176048.66755433296, 189975.29644566702)
# (170602.59755433298, 184529.22644566704)
# (171970.67755433297, 185897.30644566703)
# (176816.98955433298, 190743.61844566703)
# (174275.643554333, 188202.27244566704)
# (173055.97155433297, 186982.60044566702)
# (170764.97155433297, 184691.60044566702)
# (175539.10755433296, 189465.73644566702)
# (174902.73955433298, 188829.36844566703)
# (174421.59155433296, 188348.22044566702)
# (169977.21355433296, 183903.84244566702)
# (176805.26355433298, 190731.89244566704)
# (173860.45955433298, 187787.08844566703)
# (167530.17155433298, 181456.80044566703)
# (169712.52155433298, 183639.15044566704)
# (168114.113554333, 182040.74244566704)
# (175098.65755433298, 189025.28644566704)
# ...

# %%
#plt.figure(figsize=(13,9))

yerr_values = [abs(top-bot)/2 for top,bot in intervals]

plt.errorbar(x=np.arange(0.1,25,1),y=sample_means,yerr=yerr_values,fmt='o')

plt.hlines(xmin=0,xmax=25,
          y = house_df["SalePrice"].mean(), linewidth=2.0, color="red")

plt.title('Confidence Intervals for 25 Trials', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Confidence Intervals for 25 Trials')

# %% [markdown]
# ### Price of OldToun really different from House Price of Other neighboorhoods

# %%
from statsmodels.stats.weightstats import ztest

z_statistic, p_value = ztest(x1= house_df[house_df["Neighborhood"]=="OldTown"]["SalePrice"],
                            value = house_df["SalePrice"].mean())

print(f"Z-statastic : {z_statistic}")
print(f"P-value : {p_value}")
# Out:
# Z-statastic : -10.639294263334575
# P-value : 1.9560526026260018e-26

# %% [markdown]
# - We reject the Null hypothesis

# %%
from scipy.stats import binom

# %%
prob = []
for i in range(1,25):
    prob.append(binom.pmf(k=i,n=25,p=0.65))

plt.bar(x=np.arange(1,25),height=prob)
# Out:
# <BarContainer object of 24 artists>

# %%
prob = []
for i in range(1,25):
    prob.append(binom.cdf(k=i,n=25,p=0.65))

plt.bar(x=np.arange(1,25),height=prob)
# Out:
# <BarContainer object of 24 artists>

# %%
binom.cdf(k=2,p=0.06,n=20)
# Out:
# 0.8850275957378549

# %%
prob = []
for i in range(1,25):
    prob.append(binom.pmf(k=i,n=25,p=0.06))

plt.bar(x=np.arange(1,25),height=prob)
# Out:
# <BarContainer object of 24 artists>
