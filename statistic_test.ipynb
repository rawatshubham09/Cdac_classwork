# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Datasets\\blood_pressure.csv")

# %%
df.head()

# %%
from statsmodels.stats.weightstats import ztest

# %%
before_mean = df["bp_before"].mean()
after_mean = df["bp_after"].mean()

# %%
ztest(x1=df["bp_before"], x2=df["bp_after"])
# Out:
# (3.0669836819036274, 0.002162306611369422)

# %%
pd.set_option("display.max_columns",None)

# %%
df = pd.read_csv("C:\\Datasets\\HR-Employee-Attrition.csv")
df.sample(5)
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 147   41        No  Travel_Frequently        857  Research & Development
# 749   52       Yes      Travel_Rarely        266                   Sales
# 708   36        No         Non-Travel       1229                   Sales
# 307   38        No      Travel_Rarely        849  Research & Development
# 736   48        No      Travel_Rarely       1355  Research & Development
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# 147                10          3     Life Sciences              1
# 749                 2          1         Marketing              1
# 708                 8          4  Technical Degree              1
# 307                25          2     Life Sciences              1
# 736                 4          4     Life Sciences              1
#
#      EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %%
df.describe(include="all")
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %%
df = df.drop(columns="Over18")

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
